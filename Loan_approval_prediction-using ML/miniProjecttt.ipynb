# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## DATAFRAME CREATION

# %%
df = pd.read_csv('loanapprovaldataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.xticks(rotation=90)  # Rotate the x-axis labels to be vertical
plt.show()

# %%
print('Number of people who took loan by Education')
print(df[' education'].value_counts())
sns.countplot(x=' education',data = df, palette='Set1')
# Out:
# Number of people who took loan by Education
#  education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64
# <Axes: xlabel=' education', ylabel='count'>

# %%
print('Number of people who took loan by Self_employed')
print(df[' self_employed'].value_counts())
sns.countplot(x=' self_employed',data = df, palette='Set1')
# Out:
# Number of people who took loan by Self_employed
#  self_employed
# Yes    2150
# No     2119
# Name: count, dtype: int64
# <Axes: xlabel=' self_employed', ylabel='count'>

# %%
print('Number of people who took loan by no_of_dependents')
print(df[' no_of_dependents'].value_counts())
sns.countplot(x=' no_of_dependents',data = df, palette='Set1')
# Out:
# Number of people who took loan by no_of_dependents
#  no_of_dependents
# 4    752
# 3    727
# 0    712
# 2    708
# 1    697
# 5    673
# Name: count, dtype: int64
# <Axes: xlabel=' no_of_dependents', ylabel='count'>

# %%
# Select only numeric columns for correlation computation
numeric_df = df.select_dtypes(include=[float, int])

# Compute the correlation matrix
corr = numeric_df.corr()

# Print the correlation matrix to verify
print(corr)

# Create a heatmap using the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='BuPu')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#                             loan_id   no_of_dependents   income_annum  \
# loan_id                    1.000000           0.005326       0.012592
#  no_of_dependents          0.005326           1.000000       0.007266
#  income_annum              0.012592           0.007266       1.000000
#  loan_amount               0.008170          -0.003366       0.927470
#  loan_term                 0.009809          -0.020111       0.011488
#  cibil_score               0.016323          -0.009998      -0.023034
#  residential_assets_value  0.020936           0.007376       0.636841
#  commercial_assets_value   0.018595          -0.001531       0.640328
#  luxury_assets_value      -0.000862           0.002817       0.929145
#  bank_asset_value          0.010765           0.011163       0.851093
#
#                             loan_amount   loan_term   cibil_score  \
# loan_id                        0.008170    0.009809      0.016323
# ...

# %%
df = pd.read_csv('loanapprovaldataset.csv')
df.head(10)
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
# 5        6                  0       Graduate            Yes        4800000
# 6        7                  5       Graduate             No        8700000
# 7        8                  2       Graduate            Yes        5700000
# 8        9                  0       Graduate            Yes         800000
# 9       10                  5   Not Graduate             No        1100000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# ...

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

sns.histplot(data=df, x=" income_annum", kde=True, ax=axs[0, 0], color='green')
sns.histplot(data=df, x=" residential_assets_value", kde=True, ax=axs[0, 1], color='skyblue')
sns.histplot(data=df, x=" commercial_assets_value", kde=True, ax=axs[1, 0], color='orange')
# Out:
# <Axes: xlabel=' commercial_assets_value', ylabel='Count'>

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
sns.histplot(data=df, x=" luxury_assets_value", kde=True, ax=axs[1, 0], color='purple')
sns.histplot(data=df, x=" cibil_score", kde=True, ax=axs[1, 0], color='green')
sns.histplot(data=df, x=" bank_asset_value", kde=True, ax=axs[1, 0], color='orange');

# %%
# Encoding Technique : Label Encoding, One Hot Encoding

from sklearn.preprocessing import LabelEncoder
cols = [' education',' self_employed',' loan_status']
le =  LabelEncoder()
for col in cols:
  df[col] =  le.fit_transform(df[col])

# %%
df.head(10)
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           0               0        9600000
# 1        2                  0           1               1        4100000
# 2        3                  3           0               0        9100000
# 3        4                  3           0               0        8200000
# 4        5                  5           1               1        9800000
# 5        6                  0           0               1        4800000
# 6        7                  5           0               0        8700000
# 7        8                  2           0               1        5700000
# 8        9                  0           0               1         800000
# 9       10                  5           1               0        1100000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# ...

# %%
#This is just to assign 1 to graduate and 0 to not graduate because it was done ulta in the encoding above
#Same done with loan status, assigning 1 to approved and 0 to rejected (self employed was fine, so didnt change)

mapping = {0: 1, 1: 0}
df[' education'] = df[' education'].replace(mapping)

mapping = {0: 1, 1: 0}
df[' loan_status'] = df[' loan_status'].replace(mapping)

# %%
df.head(10)
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           1               0        9600000
# 1        2                  0           0               1        4100000
# 2        3                  3           1               0        9100000
# 3        4                  3           1               0        8200000
# 4        5                  5           0               1        9800000
# 5        6                  0           1               1        4800000
# 6        7                  5           1               0        8700000
# 7        8                  2           1               1        5700000
# 8        9                  0           1               1         800000
# 9       10                  5           0               0        1100000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# ...

# %%
df.dtypes
# Out:
# loan_id                      int64
#  no_of_dependents            int64
#  education                   int32
#  self_employed               int32
#  income_annum                int64
#  loan_amount                 int64
#  loan_term                   int64
#  cibil_score                 int64
#  residential_assets_value    int64
#  commercial_assets_value     int64
#  luxury_assets_value         int64
#  bank_asset_value            int64
#  loan_status                 int32
# dtype: object

# %%
# Split Independent and dependent features

X = df.drop(columns = ['loan_id',' loan_status'],axis = 1)
y = df[' loan_status']

# %%
X
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name:  loan_status, Length: 4269, dtype: int32

# %%
df[' loan_status'].value_counts()
# Out:
#  loan_status
# 1    2656
# 0    1613
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
# Initialize the RandomForestClassifier
RFmodel = RandomForestClassifier()

# Perform k-fold cross-validation (e.g., k=5)
k = 10
cv_scores = cross_val_score(RFmodel, X, y, cv=k)

# Print the cross-validated scores and mean accuracy
print(f'Cross-validated scores (k={k}): {cv_scores}')
print(f'Mean cross-validated accuracy: {cv_scores.mean() * 100:.2f}%')

# Train the RandomForestClassifier on the training data
RFmodel.fit(X_train, y_train)

# Predict on the test data
y_pred_RFmodel = RFmodel.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred_RFmodel)
print(f'Accuracy score of Random Forest: {accuracy * 100:.2f}%')

# Assuming you have true labels (y_test) and predicted labels (y_pred)
y_true = y_test
y_pred = y_pred_RFmodel  # Replace with your predicted labels

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Print the confusion matrix
print("Confusion Matrix:\n", cm)
# Out:
# Cross-validated scores (k=10): [0.98360656 0.99063232 0.97189696 0.99297424 0.9882904  0.98594848
#  0.98594848 0.9765808  0.98126464 0.98826291]
# Mean cross-validated accuracy: 98.45%
# Accuracy score of Random Forest: 97.74%
# Confusion Matrix:
#  [[453  18]
#  [ 11 799]]

# %%
# Evaluate the model on training data
train_accuracy = RFmodel.score(X_train, y_train)
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')

# Evaluate the model on test data
test_accuracy = RFmodel.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Check the difference
accuracy_difference = train_accuracy - test_accuracy
print(f'Accuracy Difference: {accuracy_difference * 100:.2f}%')
# Out:
# Training Accuracy: 100.00%
# Test Accuracy: 97.15%
# Accuracy Difference: 2.85%

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(RFmodel, X, y, cv=10, n_jobs=-1, train_sizes=np.linspace(0.1, 0.9, 10))

train_scores_mean = np.mean(train_scores, axis=1)
val_scores_mean = np.mean(val_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training score')
plt.plot(train_sizes, val_scores_mean, 'o-', color='g', label='Validation score')

# Set limits to start from the origin
#plt.ylim(0.7, 1)  # Assuming score ranges from 0 to 1

plt.xlabel('Training Examples')
plt.ylabel('Score')
plt.legend(loc='best')
plt.title('Learning Curves')
plt.show()

# %%
from sklearn.model_selection import validation_curve

param_range = np.arange(1, 101, 10)
train_scores, val_scores = validation_curve(RFmodel, X, y, param_name="n_estimators", param_range=param_range, cv=5)

train_scores_mean = np.mean(train_scores, axis=1)
val_scores_mean = np.mean(val_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(param_range, train_scores_mean, 'o-', color='r', label='Training score')
plt.plot(param_range, val_scores_mean, 'o-', color='g', label='Validation score')
plt.xlabel('Number of Estimators')
plt.ylabel('Score')
plt.legend(loc='best')
plt.title('Validation Curve for RandomForest')
plt.show()

# %%
param_range = np.arange(1, 21)
train_scores, val_scores = validation_curve(RFmodel, X, y, param_name="max_depth", param_range=param_range, cv=5)

train_scores_mean = np.mean(train_scores, axis=1)
val_scores_mean = np.mean(val_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(param_range, train_scores_mean, 'o-', color='r', label='Training score')
plt.plot(param_range, val_scores_mean, 'o-', color='g', label='Validation score')
plt.xlabel('Max Depth')
plt.ylabel('Score')
plt.legend(loc='best')
plt.title('Validation Curve for RandomForest Max Depth')
plt.show()

# %%
# Extract feature importances
importances = RFmodel.feature_importances_
feature_names = X.columns

# Create a DataFrame for better visualization
feature_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)

# Print the feature importances
print("Feature Importances:\n", feature_importances)
# Out:
# Feature Importances:
#                        Feature  Importance
# 6                 cibil_score    0.815322
# 5                   loan_term    0.056823
# 4                 loan_amount    0.027746
# 9         luxury_assets_value    0.018815
# 7    residential_assets_value    0.018571
# 3                income_annum    0.017578
# 8     commercial_assets_value    0.016229
# 10           bank_asset_value    0.015940
# 0            no_of_dependents    0.007789
# 2               self_employed    0.002733
# 1                   education    0.002452

# %%
# Plot feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importances')
plt.show()

# %%
from sklearn.inspection import PartialDependenceDisplay

# Assuming you have your trained Random Forest model (RFmodel_optimized) and the dataset (X)

features = [0, 1, 2, 6, 5]  # List of feature indices you want to plot partial dependence for

# Create partial dependence plots
PartialDependenceDisplay.from_estimator(RFmodel, X, features, kind='both')
plt.show()
